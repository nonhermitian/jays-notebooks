# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
import numpy as np
cregx = ClassicalRegister(1, 'x_{meas}')
cregz = ClassicalRegister(1, 'z_{meas}')
qreg = QuantumRegister(3, 'q')
circuit = QuantumCircuit(qreg,cregz, cregx)
circuit.initialize([1/np.sqrt(2), -1/np.sqrt(2)], 0)
circuit.reset([1,2])
circuit.barrier()
circuit.h(1)
circuit.cx(1, 2)
circuit.barrier()
circuit.cx(0, 1)
circuit.h(0)
circuit.barrier()
circuit.measure([0,1], [0,1])
circuit.barrier()
circuit.z(2).c_if(cregz, 1)
circuit.x(2).c_if(cregx, 1)
circuit.barrier()
circuit.reset([0,1])
circuit.draw(output='mpl')

# %%
from qiskit import BasicAer, assemble

backend = BasicAer.get_backend('statevector_simulator')
job = backend.run(circuit)
job.result().get_statevector()
# Out:
# ---------------------------------------------------------------------------
# BasicAerError                             Traceback (most recent call last)
# Cell In[5], line 4
#       1 from qiskit import BasicAer, assemble
#       3 backend = BasicAer.get_backend('statevector_simulator')
# ----> 4 job = backend.run(circuit)
#       5 job.result().get_statevector()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/qiskit_env/lib/python3.11/site-packages/qiskit/utils/deprecation.py:182, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     169 @functools.wraps(func)
#     170 def wrapper(*args, **kwargs):
#     171     _maybe_warn_and_rename_kwarg(
#     172         args,
#     173         kwargs,
#    (...)
#     180         predicate=predicate,
#     181     )
# --> 182     return func(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/qiskit_env/lib/python3.11/site-packages/qiskit/providers/basicaer/qasm_simulator.py:424, in QasmSimulatorPy.run(self, qobj, **backend_options)
#     422 self._set_options(qobj_config=qobj_options, backend_options=backend_options)
#     423 job_id = str(uuid.uuid4())
# --> 424 job = BasicAerJob(self, job_id, self._run_job(job_id, qobj))
#     425 return job
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/qiskit_env/lib/python3.11/site-packages/qiskit/providers/basicaer/qasm_simulator.py:444, in QasmSimulatorPy._run_job(self, job_id, qobj)
#     442 start = time.time()
#     443 for experiment in qobj.experiments:
# --> 444     result_list.append(self.run_experiment(experiment))
#     445 end = time.time()
#     446 result = {
#     447     "backend_name": self.name(),
#     448     "backend_version": self._configuration.backend_version,
#    (...)
#     455     "header": qobj.header.to_dict(),
#     456 }
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/qiskit_env/lib/python3.11/site-packages/qiskit/providers/basicaer/qasm_simulator.py:619, in QasmSimulatorPy.run_experiment(self, experiment)
#     617         backend = self.name()
#     618         err_msg = '{0} encountered unrecognized operation "{1}"'
# --> 619         raise BasicAerError(err_msg.format(backend, operation.name))
#     621 # Add final creg data to memory list
#     622 if self._number_of_cmembits > 0:
#
# BasicAerError: 'statevector_simulator encountered unrecognized operation "initialize"'

# %%
from qiskit import QuantumCircuit
from qiskit.compiler import transpile

# %%
circuit = QuantumCircuit(3, 3)
circuit.ccx(0,1,2)
circuit.measure([0,1, 2], [0,1, 2])
circuit.draw()
# Out:
#           ┌─┐
# q_0: ──■──┤M├──────
#        │  └╥┘┌─┐
# q_1: ──■───╫─┤M├───
#      ┌─┴─┐ ║ └╥┘┌─┐
# q_2: ┤ X ├─╫──╫─┤M├
#      └───┘ ║  ║ └╥┘
# c: 3/══════╩══╩══╩═
#            0  1  2

# %%
circuit_ibm = transpile(circuit, basis_gates = ['cz', 'sx', 'rz'], coupling_map =[[0, 1], [1, 2]] , optimization_level=1)
circuit_ibm.draw()
# Out:
# global phase: 5π/8
#                                                                            »
# q_1 -> 0 ─■────────────────────────────────────────────────────────────────»
#           │ ┌──────────┐┌────┐┌───────────┐┌────┐┌──────────┐   ┌─────────┐»
# q_2 -> 1 ─■─┤ Rz(-π/2) ├┤ √X ├┤ Rz(-3π/4) ├┤ √X ├┤ Rz(-π/2) ├─■─┤ Rz(π/2) ├»
#             └──────────┘└────┘└───────────┘└────┘└──────────┘ │ └─────────┘»
# q_0 -> 2 ─────────────────────────────────────────────────────■────────────»
#                                                                            »
#     c: 3/══════════════════════════════════════════════════════════════════»
#                                                                            »
# «                                                ┌─────────┐       »
# «q_1 -> 0 ─────────────────────────────────────■─┤ Rz(π/4) ├───────»
# «         ┌────┐┌───────────┐┌────┐┌─────────┐ │ ├─────────┴┐┌────┐»
# «q_2 -> 1 ┤ √X ├┤ Rz(-3π/4) ├┤ √X ├┤ Rz(π/2) ├─■─┤ Rz(-π/2) ├┤ √X ├»
# «         └────┘└───────────┘└────┘└─────────┘   └──────────┘└────┘»
# «q_0 -> 2 ─────────────────────────────────────────────────────────»
# «                                                                  »
# «    c: 3/═════════════════════════════════════════════════════════»
# «                                                                  »
# «                                                                           »
# «q_1 -> 0 ────────────────────────────────────────────────────────────────■─»
# «         ┌───────────┐┌────┐┌──────────┐   ┌─────────┐┌────┐┌──────────┐ │ »
# «q_2 -> 1 ┤ Rz(-3π/4) ├┤ √X ├┤ Rz(-π/2) ├─■─┤ Rz(π/2) ├┤ √X ├┤ Rz(3π/4) ├─■─»
# «         └───────────┘└────┘└──────────┘ │ └─────────┘└────┘└──────────┘   »
# «q_0 -> 2 ────────────────────────────────■─────────────────────────────────»
# «                                                                           »
# «    c: 3/══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «         ┌─────────┐┌────┐┌─────────┐   ┌─────────┐┌────┐┌─────────┐      »
# «q_1 -> 0 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─■─┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─■────»
# «         ├─────────┤├────┤├─────────┤ │ ├─────────┤├────┤├─────────┤ │    »
# «q_2 -> 1 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─■─┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├─■──■─»
# «         └─────────┘└────┘└─────────┘   └─────────┘└────┘└─────────┘    │ »
# «q_0 -> 2 ───────────────────────────────────────────────────────────────■─»
# «                                                                          »
# «    c: 3/═════════════════════════════════════════════════════════════════»
# «                                                                          »
# «                                                                              »
# «q_1 -> 0 ─────────────────────────────────────────────────────────────────────»
# «         ┌──────────┐┌────┐┌───────────┐┌────┐┌──────────┐   ┌─────────┐┌────┐»
# «q_2 -> 1 ┤ Rz(-π/2) ├┤ √X ├┤ Rz(-3π/4) ├┤ √X ├┤ Rz(-π/2) ├─■─┤ Rz(π/2) ├┤ √X ├»
# «         ├─────────┬┘└────┘└───────────┘└────┘└──────────┘ │ └─────────┘└────┘»
# «q_0 -> 2 ┤ Rz(π/4) ├───────────────────────────────────────■──────────────────»
# «         └─────────┘                                                          »
# «    c: 3/═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                     ░       ┌─┐
# «q_1 -> 0 ────────────░───────┤M├
# «         ┌─────────┐ ░    ┌─┐└╥┘
# «q_2 -> 1 ┤ Rz(π/2) ├─░────┤M├─╫─
# «         └─────────┘ ░ ┌─┐└╥┘ ║
# «q_0 -> 2 ────────────░─┤M├─╫──╫─
# «                     ░ └╥┘ ║  ║
# «    c: 3/═══════════════╩══╩══╩═
# «                        0  1  2

# %%
circuit_ibm = transpile(circuit, basis_gates = ['cz', 'sx', 'rz'], coupling_map =[[0, 1], [1, 2]] , optimization_level=2)
circuit_ibm.draw()
# Out:
#                                                                              »
# q_1 -> 0 ─■──────────────────────────────────────────────────────────────────»
#           │ ┌──────────┐┌────┐┌───────────┐┌────┐   ┌────┐┌───────────┐┌────┐»
# q_2 -> 1 ─■─┤ Rz(-π/2) ├┤ √X ├┤ Rz(-3π/4) ├┤ √X ├─■─┤ √X ├┤ Rz(-3π/4) ├┤ √X ├»
#             └──────────┘└────┘└───────────┘└────┘ │ └────┘└───────────┘└────┘»
# q_0 -> 2 ─────────────────────────────────────────■──────────────────────────»
#                                                                              »
#     c: 3/════════════════════════════════════════════════════════════════════»
#                                                                              »
# «            ┌──────────┐                                           ┌────┐»
# «q_1 -> 0 ─■─┤ Rz(3π/4) ├─────────────────────────────────────────■─┤ √X ├»
# «          │ └──┬────┬──┘┌───────────┐┌────┐   ┌────┐┌──────────┐ │ ├────┤»
# «q_2 -> 1 ─■────┤ √X ├───┤ Rz(-3π/4) ├┤ √X ├─■─┤ √X ├┤ Rz(5π/4) ├─■─┤ √X ├»
# «               └────┘   └───────────┘└────┘ │ └────┘└──────────┘   └────┘»
# «q_0 -> 2 ───────────────────────────────────■────────────────────────────»
# «                                                                         »
# «    c: 3/════════════════════════════════════════════════════════════════»
# «                                                                         »
# «         ┌───────┐   ┌────┐┌─────────┐                                       »
# «q_1 -> 0 ┤ Rz(π) ├─■─┤ √X ├┤ Rz(π/2) ├─■─────────────────────────────────────»
# «         ├───────┤ │ ├────┤└─────────┘ │       ┌────┐  ┌───────────┐┌────┐   »
# «q_2 -> 1 ┤ Rz(π) ├─■─┤ √X ├────────────■──■────┤ √X ├──┤ Rz(-3π/4) ├┤ √X ├─■─»
# «         └───────┘   └────┘               │ ┌──┴────┴─┐└───────────┘└────┘ │ »
# «q_0 -> 2 ─────────────────────────────────■─┤ Rz(π/4) ├────────────────────■─»
# «                                            └─────────┘                      »
# «    c: 3/════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                           ░       ┌─┐
# «q_1 -> 0 ──────────────────░───────┤M├
# «         ┌────┐┌─────────┐ ░    ┌─┐└╥┘
# «q_2 -> 1 ┤ √X ├┤ Rz(π/2) ├─░────┤M├─╫─
# «         └────┘└─────────┘ ░ ┌─┐└╥┘ ║
# «q_0 -> 2 ──────────────────░─┤M├─╫──╫─
# «                           ░ └╥┘ ║  ║
# «    c: 3/═════════════════════╩══╩══╩═
# «                              0  1  2

# %%
circuit_ibm = transpile(circuit, basis_gates = ['cz', 'sx', 'rz'], coupling_map =[[0, 1], [1, 2]] , optimization_level=3)
circuit_ibm.draw()
# Out:
#                                                                              »
# q_1 -> 0 ─■──────────────────────────────────────────────────────────────────»
#           │ ┌──────────┐┌────┐┌───────────┐┌────┐   ┌────┐┌───────────┐┌────┐»
# q_2 -> 1 ─■─┤ Rz(-π/2) ├┤ √X ├┤ Rz(-3π/4) ├┤ √X ├─■─┤ √X ├┤ Rz(-3π/4) ├┤ √X ├»
#             └──────────┘└────┘└───────────┘└────┘ │ └────┘└───────────┘└────┘»
# q_0 -> 2 ─────────────────────────────────────────■──────────────────────────»
#                                                                              »
#     c: 3/════════════════════════════════════════════════════════════════════»
#                                                                              »
# «            ┌──────────┐    ┌────┐                                         »
# «q_1 -> 0 ─■─┤ Rz(3π/4) ├────┤ √X ├─────────────────────────────────────────»
# «          │ └──┬────┬──┘┌───┴────┴──┐┌────┐┌────────┐   ┌────┐┌───────────┐»
# «q_2 -> 1 ─■────┤ √X ├───┤ Rz(-3π/4) ├┤ √X ├┤ Rz(-π) ├─■─┤ √X ├┤ Rz(-3π/4) ├»
# «               └────┘   └───────────┘└────┘└────────┘ │ └────┘└───────────┘»
# «q_0 -> 2 ─────────────────────────────────────────────■────────────────────»
# «                                                                           »
# «    c: 3/══════════════════════════════════════════════════════════════════»
# «                                                                           »
# «                     ┌────┐            ┌────────┐┌────┐┌────────┐             »
# «q_1 -> 0 ───────■────┤ √X ├──────────■─┤ Rz(-π) ├┤ √X ├┤ Rz(-π) ├─■───────────»
# «         ┌────┐ │ ┌──┴────┴──┐┌────┐ │ └─┬────┬─┘└────┘└────────┘ │ ┌────────┐»
# «q_2 -> 1 ┤ √X ├─■─┤ Rz(-π/2) ├┤ √X ├─■───┤ √X ├───────────────────■─┤ Rz(-π) ├»
# «         └────┘   └──────────┘└────┘     └────┘                     └────────┘»
# «q_0 -> 2 ─────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «    c: 3/═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                                     ░       »
# «q_1 -> 0 ────────────────────────────────────────────────────────────░───────»
# «         ┌────┐      ┌────┐  ┌───────────┐┌────┐   ┌────┐┌─────────┐ ░    ┌─┐»
# «q_2 -> 1 ┤ √X ├─■────┤ √X ├──┤ Rz(-3π/4) ├┤ √X ├─■─┤ √X ├┤ Rz(π/2) ├─░────┤M├»
# «         └────┘ │ ┌──┴────┴─┐└───────────┘└────┘ │ └────┘└─────────┘ ░ ┌─┐└╥┘»
# «q_0 -> 2 ───────■─┤ Rz(π/4) ├────────────────────■───────────────────░─┤M├─╫─»
# «                  └─────────┘                                        ░ └╥┘ ║ »
# «    c: 3/═══════════════════════════════════════════════════════════════╩══╩═»
# «                                                                        0  1 »
# «         ┌─┐
# «q_1 -> 0 ┤M├
# «         └╥┘
# «q_2 -> 1 ─╫─
# «          ║
# «q_0 -> 2 ─╫─
# «          ║
# «    c: 3/═╩═
# «          2
